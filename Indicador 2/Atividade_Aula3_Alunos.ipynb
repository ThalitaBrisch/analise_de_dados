# %%
import pandas as pd

# %%
path = (r"H:\Python\Terceira Etapa\Indicador 2\Tabela_11_Domicilios_sem_presenca_de_conjuge_e_com_filhos.xlsx")

# %%
formacao_bruto = pd.read_excel(path, header=None)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\compat\_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File c:\Program Files\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
formacao_bruto
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 formacao_bruto
#
# NameError: name 'formacao_bruto' is not defined

# %% [markdown]
# ]A tabela deverá ser dividida em 3
# - homens e mulheres por região com curso superior
# - homens e mulheres por região com curso nas áreas de Ciência, Tecnologia, Engenharias e Matemática
# - homens e mulheres por região com curso nas áreas de Educação, Serviços pessoais, Saúde e Bem-estar

# %% [markdown]
# Exemplo 1

# %%
# : = todas as linhas  |  0:4 = colunas 0, 1, 2 e 3 (as 4 primeiras)
formacao_total = formacao_bruto.iloc[3:36, 0:4].copy()

# %%
formacao_total.columns = [
    "uf_regiao",
    "total",
    "total_homens",
    "total_mulheres"
]

# %%
formacao_total

# %%
formacao_total["percentual_mulheres"] = ((formacao_total['total_mulheres'] / formacao_total['total']) * 100).round(2)

# %%
formacao_ciencias = formacao_bruto.iloc[3:36, 4:8].copy()

formacao_ciencias.columns = [
    "uf_regiao",
    "total",
    "total_homens",
    "total_mulheres"
]

formacao_ciencias

# %%
formacao_ciencias["percentual_mulheres"] = (
    (formacao_ciencias["total_mulheres"] / formacao_ciencias["total"]) * 100
).round(2)

# %%
formacao_educacao = formacao_bruto.iloc[3:36, 8:12].copy()

formacao_educacao.columns = [
    "uf_regiao",
    "total",
    "total_homens",
    "total_mulheres"
]

formacao_educacao

# %%
formacao_educacao["percentual_mulheres"] = (
    (formacao_educacao["total_mulheres"] / formacao_educacao["total"]) * 100
).round(2)
